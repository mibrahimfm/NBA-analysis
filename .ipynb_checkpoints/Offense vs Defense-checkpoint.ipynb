# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
TEAMS= ["ATL", "BOS", "BRK", "CHI", "CHO", "CLE", "DAL", "DEN", "DET", "GSW", "HOU", "IND", "LAC", "LAL", "MEM", "MIA", "MIL", "MIN", "NOP", "NYK", "OKC", "ORL", "PHI", "PHO", "POR", "SAC", "SAS", "TOR", "UTA", "WAS"]
WESTERN_CONF_TEAMS = ["DAL", "DEN", "GSW", "HOU", "LAC", "LAL", "MEM", "MIN", "NOP", "OKC", "PHO", "POR", "SAC", "SAS", "UTA"]
EASTERN_CONF_TEAMS = ["ATL", "BOS", "BRK", "CHI", "CHO", "CLE", "DET", "IND", "MIA", "MIL", "NYK", "ORL", "PHI", "TOR", "WAS"]
SEASONS = [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
def mean(data):
    return sum(data) / len(data)

# %%
def variance(data):
    n = len(data)
    avg = mean(data)
    
    deviations = [(x - avg) ** 2 for x in data]
    
    variance = sum(deviations) / n
    return variance

# %%
def std(data):
    var = variance(data)
    std = var ** 0.5
    return std

# %%
def format_season(season):
        #Formats years in season to use in File Name
        #Ex: 2021 turns into 2020-21
        first_year = season-1
        second_year = str(season)[2:]
        
        return first_year, second_year

# %%
def get_csvs_by_season(season):
    first_year, second_year = format_season(season)
    
    player_df = pd.read_csv("Player_Stats/player_stats_{0}-{1}.csv".format(first_year, second_year))
    team_df = pd.read_csv("Team_Stats/team_stats_{0}-{1}.csv".format(first_year, second_year))
    adv_team_df = pd.read_csv("Advanced_Team_Stats/adv_team_stats_{0}-{1}.csv".format(first_year, second_year))
    
    return player_df, team_df, adv_team_df

# %%
player_dfs, team_dfs, adv_team_dfs = [], [], []

for season in SEASONS:
    player_df, team_df, adv_team_df = get_csvs_by_season(season)
    player_dfs.append(player_df)
    team_dfs.append(team_df)
    adv_team_dfs.append(adv_team_df)

# %%
avg_off_ratings = []
avg_def_ratings = []

for i in range(len(SEASONS)):
    off_ratings = adv_team_dfs[i]["ORtg"]
    def_ratings = adv_team_dfs[i]["DRtg"]
    
    avg_off_ratings.append(mean(off_ratings))
    avg_def_ratings.append(mean(def_ratings))
    
print(avg_off_ratings)
print(avg_def_ratings)
# Out:
# [103.02758620689654, 104.51379310344826, 103.63448275862069, 102.91034482758621, 106.06666666666663, 106.21333333333332, 106.43999999999998, 107.48, 108.26333333333334, 107.57666666666664, 107.25666666666665, 104.59000000000002, 105.83666666666666, 106.64999999999999, 105.64000000000003, 106.3933333333333, 108.80999999999997, 108.61666666666666, 110.40000000000002, 110.49999999999999, 112.35333333333332]
# [103.01379310344831, 104.53103448275861, 103.62413793103448, 102.8896551724138, 106.07333333333332, 106.2, 106.43333333333335, 107.46666666666667, 108.22666666666666, 107.55333333333333, 107.22666666666666, 104.6, 105.8433333333333, 106.64333333333333, 105.64999999999999, 106.39333333333333, 108.77999999999999, 108.60666666666664, 110.40333333333332, 110.68000000000002, 112.33000000000001]

# %%
adv_team_dfs[1]
# Out:
#    Team   Age     W     L  PW  PL   MOV   SOS   SRS   ORtg  ...  Off_ORB%  \
# 0   SAC  27.0  61.0  21.0  61  21  7.61  0.00  7.61  109.0  ...      27.9
# 1   LAL  27.9  58.0  24.0  60  22  7.12  0.03  7.15  109.4  ...      28.8
# 2   SAS  28.5  58.0  24.0  59  23  6.21  0.07  6.28  106.5  ...      27.2
# 16       0.225     0.477      12.1      69.9       0.194
# 17       0.189     0.471      14.7      70.1       0.237
# 18       0.180     0.476      14.4      70.2       0.227
# 19       0.214     0.484      13.0      71.4       0.214
# 20       0.194     0.455      13.6      74.0       0.249
# 21       0.232     0.493      12.3      72.8       0.226
# 22       0.216     0.479      12.9      71.9       0.236
# 23       0.225     0.495      14.1      70.9       0.218
# 24       0.211     0.491      11.5      69.8       0.178
# 25       0.242     0.488      12.9      69.4       0.232
# 26       0.190     0.492      13.6      69.9       0.245
# 27       0.204     0.486      13.7      68.0       0.197
# 28       0.218     0.497      13.7      71.4       0.239
#
#                          Arena  Attend.  Attend./G  Made_Playoffs
# 0              ARCO Arena (II)   709997      17317           True
# 1               STAPLES Center   778777      18995           True
# 2                    Alamodome   906390      22107           True
# 3   Continental Airlines Arena   564194      13761           True
# 4     American Airlines Center   802783      19580           True
# 5                Target Center   731673      17846           True
# 6            Rose Garden Arena   797821      19459           True
# 7   KeyArena at Seattle Center   633516      15452           True
# 8                  FleetCenter   659751      16091           True
# 9   The Palace of Auburn Hills   760807      18556           True
# 10          First Union Center   842976      20560           True
# 11        TD Waterhouse Centre   621121      15149           True
# 12                Delta Center   766108      18686           True
# 13          Charlotte Coliseum   462738      11286           True
# 14          Conseco Fieldhouse   686537      16745           True
# 15              Bradley Center   745305      18178          False
# 16              STAPLES Center   740185      18053          False
# 17           Air Canada Centre   810160      19760           True
# 18          America West Arena   668939      16316          False
# 19                  MCI Center   847634      20674          False
# 20      AmericanAirlines Arena   655549      15989          False
# 21                  Gund Arena   596115      14539          False
# 22  Madison Square Garden (IV)   810283      19763          False
# 23               Philips Arena   506110      12344          False
# 24               Compaq Center   481227      11737          False
# 25        The Arena in Oakland   593182      14468          False
# 26                Pepsi Center   633846      15460          False
# 27               Pyramid Arena   591030      14415          False
# 28               United Center   776311      18934          False
#
# [29 rows x 28 columns]

# %%
diffs_rtg = []

for i in range(len(SEASONS)):
    off_rating_playoff_teams = []
    def_rating_playoff_teams = []
    for index, row in adv_team_dfs[i].iterrows():
        if row["Made_Playoffs"]:
            off_rating_playoff_teams.append(row["ORtg"])
            def_rating_playoff_teams.append(row["DRtg"])
    
    
    ortg_diff = mean(off_rating_playoff_teams) - avg_off_ratings[i]
    drtg_diff = mean(def_rating_playoff_teams) - avg_def_ratings[i]

    diffs_rtg.append((ortg_diff, drtg_diff))
  
# print(diffs_rtg)

o_vs_d = [abs(o) - abs(d) for o, d in diffs_rtg]
o_vs_d
# Out:
# [-0.21637931034484836,
#  0.24892241379306768,
#  0.3913793103448171,
#  -0.4625000000000057,
#  -0.7649999999999579,
#  -0.8445833333333042,
#  -0.2608333333333661,
#  0.372083333333336,
#  -0.6900000000000119,
#  -0.8424999999999869,
#  -0.6020833333333258,
#  -0.6525000000000176,
#  -0.12374999999997272,
#  -0.5933333333333479,
#  0.9287500000000222,
#  0.15083333333333826,
#  0.5537500000000222,
#  0.3954166666666765,
#  0.027916666666655487,
#  -0.3050000000000068,
#  1.3791666666666629]

# %%
plt.figure(figsize=(15, 10))

aux = np.full((21, ), 0.0)

plt.plot(SEASONS, o_vs_d)
plt.plot(SEASONS, aux)
plt.xticks(SEASONS)
plt.yticks([-5.0, -2.5, -0.0, 2.5, 5.0])
plt.show()
