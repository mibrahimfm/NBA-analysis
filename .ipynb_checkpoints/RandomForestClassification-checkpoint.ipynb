# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint
from sklearn.tree import export_graphviz
from IPython.display import Image
#import graphviz

from ipynb.fs.full.UtilFunctions import format_season

# %%
def pre_process(seasons):
    df = None
    for season in seasons:
        first_year, second_year = format_season(season)
        player_data = pd.read_csv(f"DataCollection/Player_Stats/player_stats_{first_year}-{second_year}.csv")
        if season > 1997:
            shooting_data = pd.read_csv(f"DataCollection/Player_Shooting_Stats/Regular_Season/player_shooting_stats_{first_year}-{second_year}.csv")
            player_data = pd.merge(player_data, shooting_data.loc[:,~shooting_data.columns.isin(['Pos', 'Age', 'G', 'MP', 'FG%', "3PAr", "2P%", "3P%"])], on=['Player', 'Tm'])

        player_data = player_data.fillna(0)
        player_data = player_data[(player_data["MP"] > 15) & (player_data["G"] >= 30)]
        player_data = player_data.sort_values(by=['G'], ascending=False)
        player_data = player_data[player_data["Tm"] != "TOT"]
        player_data = player_data.drop_duplicates(subset ="Player",keep = "first")
        player_data.reset_index(inplace=True)
        player_data.drop(columns=['index'], inplace=True)
        
        if df is None:
            df = player_data
        else:
            df = pd.concat([df, player_data])
            
    df.reset_index(inplace=True)
    df.drop('index', axis=1, inplace=True)
    return df

# %%
def random_forest_classify(X_train, y_train, X_test):
    rf = RandomForestClassifier()
    rand_search = RandomizedSearchCV(rf, param_distributions = {'n_estimators': randint(50,500), 'max_depth': randint(1, 20)},
                                 n_iter = 5, cv = 5)
    rand_search.fit(X_train, y_train)
    best_rf = rand_search.best_estimator_

    return best_rf.predict(X_test), best_rf.feature_importances_, best_rf.estimators_

# %%
def plot_feature_importances(importances, estimators, features):
    fi = pd.Series(importances, index=features).sort_values(ascending=False)
    #std = np.std([tree.feature_importances_ for tree in estimators], axis=0)
    fig, ax = plt.subplots(figsize=(18, 18))
    ax.bar(fi.index, fi)
    ax.tick_params('x', labelrotation=90)
    ax.set_title("Feature importances using MDI")
    ax.set_ylabel("Mean decrease in impurity")

# %% [markdown]
# ## Pre-processing - gathering data from the last 6 seasons

# %%
df = pre_process(range(2017, 2023))

# %% [markdown]
# ## Feature selection, splitting into training/testing

# %%
features = df.loc[:, ~df.columns.isin(["Player", "Pos", "Tm"])]
target = df['Pos']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.2)

# %% [markdown]
# ## Randomly select better parameters for Random Forest and fit the data

# %%
y_pred, feature_importances, estimators = random_forest_classify(X_train, y_train, X_test)

# %%
plot_feature_importances(feature_importances, estimators, [c for c in df.columns if c not in ['Player', 'Pos', 'Tm']])

# %% [markdown]
# ## Evaluating Random Forest results with Confusion Matrix and accuracy score

# %%
labels = ["PG", "SG", "SF", "PF", "C"]
cm = confusion_matrix(y_test, y_pred, labels=labels)
ConfusionMatrixDisplay(cm, display_labels=labels).plot()

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.6931506849315069

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            C       0.88      0.82      0.85        74
#           PF       0.62      0.74      0.68        65
#           PG       0.77      0.81      0.78        77
#           SF       0.64      0.40      0.50        67
#           SG       0.57      0.67      0.62        82
#
#     accuracy                           0.69       365
#    macro avg       0.70      0.69      0.69       365
# weighted avg       0.70      0.69      0.69       365

# %% [markdown]
# ## Visualize trees from random forest with Graphviz

# %%
for i in range(3):
    tree = best_rf.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=X_train.columns,  
                               filled=True,  
                               max_depth=5, 
                               impurity=False, 
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %% [markdown]
# ## Repeat the random forest process, but with data from the early 2000s

# %% [markdown]
# ## Feature selection, splitting into training/testing

# %%
old_df = pre_process(range(2000, 2006))

# %%
features = old_df.loc[:, ~old_df.columns.isin(["Player", "Pos", "Tm"])]
target = old_df['Pos']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.2)

# %% [markdown]
# ## Randomly select better parameters for Random Forest and fit the data

# %%
y_pred, feature_importances, estimators = random_forest_classify(X_train, y_train, X_test)

# %%
plot_feature_importances(feature_importances, estimators, [c for c in df.columns if c not in ['Player', 'Pos', 'Tm']])

# %% [markdown]
# ## Evaluating Random Forest results with Confusion Matrix and accuracy score

# %%
labels = ["PG", "SG", "SF", "PF", "C"]
cm = confusion_matrix(y_test, y_pred, labels=labels)
ConfusionMatrixDisplay(cm, display_labels=labels).plot()

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.6476190476190476

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            C       0.70      0.77      0.73        60
#           PF       0.54      0.45      0.49        60
#           PG       0.84      0.88      0.86        58
#           SF       0.56      0.56      0.56        70
#           SG       0.60      0.61      0.61        67
#
#     accuracy                           0.65       315
#    macro avg       0.65      0.65      0.65       315
# weighted avg       0.64      0.65      0.64       315

# %% [markdown]
# ## Visualize trees from random forest with Graphviz

# %%
for i in range(3):
    tree = best_rf.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=X_train.columns,  
                               filled=True,  
                               max_depth=5, 
                               impurity=False, 
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %% [markdown]
# ## Repeat the random forest process, but training with recent seasons and predicting old ones

# %% [markdown]
# ## Splitting into training/testing

# %%
features = df.loc[:, ~df.columns.isin(["Player", "Pos", "Tm"])]
target = df['Pos']

old_features = old_df.loc[:, ~old_df.columns.isin(["Player", "Pos", "Tm"])]
old_target = old_df['Pos']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.2)
old_X_train, old_X_test, old_y_train, old_y_test = train_test_split(old_features, old_target, test_size = 0.2)

# %% [markdown]
# ## Randomly select better parameters for Random Forest and fit the data

# %%
y_pred, feature_importances, estimators = random_forest_classify(X_train, y_train, old_X_test)

# %%
plot_feature_importances(feature_importances, estimators, [c for c in df.columns if c not in ['Player', 'Pos', 'Tm']])

# %% [markdown]
# ## Evaluating Random Forest results with Confusion Matrix and accuracy score

# %%
labels = ["PG", "SG", "SF", "PF", "C"]
cm = confusion_matrix(old_y_test, y_pred, labels=labels)
ConfusionMatrixDisplay(cm, display_labels=labels).plot()

# %%
accuracy = accuracy_score(old_y_test, y_pred)
accuracy
# Out:
# 0.580952380952381

# %%
print(classification_report(old_y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            C       0.51      0.91      0.65        53
#           PF       0.44      0.32      0.37        71
#           PG       0.74      0.93      0.83        69
#           SF       0.53      0.33      0.41        63
#           SG       0.64      0.46      0.53        59
#
#     accuracy                           0.58       315
#    macro avg       0.57      0.59      0.56       315
# weighted avg       0.57      0.58      0.56       315

# %% [markdown]
# ## Visualize trees from random forest with Graphviz

# %%
for i in range(3):
    tree = best_rf.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=X_train.columns,  
                               filled=True,  
                               max_depth=5, 
                               impurity=False, 
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %% [markdown]
# ## Repeat the random forest process, but training with old seasons and predicting recent ones

# %% [markdown]
# ## Randomly select better parameters for Random Forest and fit the data

# %%
y_pred, feature_importances, estimators = random_forest_classify(old_X_train, old_y_train, X_test)

# %%
plot_feature_importances(feature_importances, estimators, [c for c in df.columns if c not in ['Player', 'Pos', 'Tm']])

# %% [markdown]
# ## Evaluating Random Forest results with Confusion Matrix and accuracy score

# %%
labels = ["PG", "SG", "SF", "PF", "C"]
cm = confusion_matrix(y_test, y_pred, labels=labels)
ConfusionMatrixDisplay(cm, display_labels=labels).plot()

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.5917808219178082

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            C       0.97      0.46      0.62        79
#           PF       0.38      0.52      0.44        58
#           PG       0.88      0.69      0.78        75
#           SF       0.41      0.61      0.49        64
#           SG       0.62      0.66      0.64        89
#
#     accuracy                           0.59       365
#    macro avg       0.65      0.59      0.59       365
# weighted avg       0.68      0.59      0.61       365

# %% [markdown]
# ## Visualize trees from random forest with Graphviz

# %%
for i in range(3):
    tree = best_rf.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=X_train.columns,  
                               filled=True,  
                               max_depth=5, 
                               impurity=False, 
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %% [markdown]
# ## Repeat the random forest process, with the first seasons with the 3-point line

# %%
first_dfs = []

# %%
for season in range(1980,1986):
    first_year, second_year = format_season(season)
    player_data = pd.read_csv(f"DataCollection/Player_Stats/player_stats_{first_year}-{second_year}.csv")    
    player_data = player_data.fillna(0)
    player_data = player_data[(player_data["MP"] > 15) & (player_data["G"] >= 30)]
    player_data = player_data.sort_values(by=['G'], ascending=False)
    player_data = player_data[player_data["Tm"] != "TOT"]
    player_data = player_data.drop_duplicates(subset ="Player",keep = "first")
    player_data.reset_index(inplace=True)
    player_data.drop(columns=['index'], inplace=True)
    
    first_dfs.append(player_data)

# %%
first_df = first_dfs[0]
for i in range(1, len(first_dfs)):
    first_df = pd.concat([first_df, first_dfs[i]])
    
first_df.reset_index(inplace=True)
first_df.drop('index', axis=1, inplace=True)

# %%
first_df = pre_process(range(1980, 1988))

# %% [markdown]
# ## Splitting into training/testing

# %%
features = first_df.loc[:, ~first_df.columns.isin(["Player", "Pos", "Tm"])]
target = first_df['Pos']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.2)

# %% [markdown]
# ## Randomly select better parameters for Random Forest and fit the data

# %%
y_pred, feature_importances, estimators = random_forest_classify(X_train, y_train, X_test)

# %%
plot_feature_importances(feature_importances, estimators, [c for c in first_df.columns if c not in ['Player', 'Pos', 'Tm']])

# %% [markdown]
# ## Evaluating Random Forest results with Confusion Matrix and accuracy score

# %%
labels = ["PG", "SG", "SF", "PF", "C"]
cm = confusion_matrix(y_test, y_pred, labels=labels)
ConfusionMatrixDisplay(cm, display_labels=labels).plot()

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7469135802469136

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            C       0.74      0.74      0.74        62
#           PF       0.67      0.60      0.63        65
#           PG       0.88      0.96      0.92        70
#           SF       0.69      0.74      0.72        70
#           SG       0.72      0.67      0.69        57
#
#     accuracy                           0.75       324
#    macro avg       0.74      0.74      0.74       324
# weighted avg       0.74      0.75      0.74       324

# %% [markdown]
# ## Visualize trees from random forest with Graphviz

# %%
for i in range(3):
    tree = best_rf.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=X_train.columns,  
                               filled=True,  
                               max_depth=5, 
                               impurity=False, 
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)
